# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mirabdulbaqi/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose **Lane 1 – Ranking Signal Analysis** because I want to build my career as a Data Analyst. I enjoy exploring data, identifying patterns, and turning numbers into useful insights that can support better decisions. This lane gives me the opportunity to investigate which content and search signals are associated with better performance using real data. I believe this project will help me strengthen my data analysis skills while learning how to answer practical business questions. My goal is to provide evidence that supports decision-making rather than relying on assumptions, while recognizing that the analysis shows relationships and patterns rather than proving cause and effect.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The main decision this project aims to improve is identifying which content and search signals are associated with better content performance so that the content and SEO teams can make more informed decisions. Based on the analysis, these teams can prioritize improvements to content, optimize existing pages, and focus on the factors that appear to be linked with stronger performance. If the recommendations are wrong, the team may spend time and resources improving the wrong pages or focusing on signals that are not actually useful, which could reduce the effectiveness of their work. This project is intended to support better decision-making by using evidence from the available data rather than assumptions alone.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
# The starter dataset contains **30,000 content pages** from **32 anonymized clients**, providing a large and diverse dataset for analysis. The average **CTR is 0.51**, while the average **search position is 16.34**, suggesting that there is variation in search performance that can be explored. These statistics support my choice of **Lane 1 – Ranking Signal Analysis**, because they indicate there is enough data to investigate how different content and search signals are associated with content performance and to provide decision-support insights.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

# Show a few useful numbers
print("Total pages:", len(df))
print("Total clients:", df["client_id"].nunique())
print("Average CTR:", round(df["ctr"].mean(), 2))
print("Average Position:", round(df["avg_position"].mean(), 2))
# Out:
# Total pages: 30000
# Total clients: 32
# Average CTR: 0.51
# Average Position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project will identify observed patterns and directional relationships between content and search signals and content performance. The findings are intended to support decision-making by providing evidence that may help content and SEO teams prioritize their work. However, this analysis cannot prove that a specific signal directly causes better rankings or higher engagement, and it cannot predict Google's ranking algorithm or guarantee future performance. Any recommendations should be treated as decision-support based on the available data rather than definitive proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
