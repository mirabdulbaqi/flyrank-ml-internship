# %%
# !git clone https://github.com/mirabdulbaqi/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
import os

os.listdir("flyrank-ml-internship/data/raw")
# Out:
# ['content_refresh_anonymized.csv']

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mirabdulbaqi/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# I chose **Ranking** as the ML task type because the goal of my project is to understand which content pages should be prioritized based on the content and search signals associated with better performance. Instead of simply predicting a category or grouping similar pages, the model would help rank content according to its expected usefulness for decision-making. This ranking can support content and SEO teams in deciding which pages to improve first, making the analysis more valuable than using a simple fixed priority list.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# For my lane, I would use **Click-Through Rate (CTR)** as the target or proxy because it is an observed outcome in the dataset that reflects how users interact with content in search results. Rather than predicting content quality directly, the model would estimate or rank content based on expected CTR to support prioritization decisions. Since CTR is measured from actual performance data, it serves as an observed outcome rather than a label created by a fixed rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# For a ranking task, I would use a ranking quality metric such as **NDCG (Normalized Discounted Cumulative Gain)** because it measures whether the most important content pages are placed near the top of the recommended ranking. A good result means that pages with stronger observed performance are prioritized correctly. This metric helps evaluate whether the ranking is useful for supporting content and SEO decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# In this project, the unit of analysis is **one content page**. Each row in the dataset represents a single content page with its associated content characteristics and search performance measurements, such as CTR, average position, engagement rate, and other features. This allows the analysis to compare pages and identify which content should be prioritized for improvement.

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

# Show the unit of analysis
columns_to_show = [
    "content_id",
    "client_id",
    "ctr",
    "avg_position",
    "engagement_rate"
]

df[columns_to_show].head()
# Out:
#              content_id          client_id   ctr  avg_position  \
# 0  content_304f48230142  client_f369cb89fc  0.76          10.6
# 1  content_a1fb4e703a9e  client_4e07408562  0.05          20.3
# 2  content_9aa793d4d895  client_7f2253d7e2  0.09          36.5
# 3  content_331d6c4de07b  client_19581e27de  0.49           6.2
# 4  content_d99b7a2d90ca  client_3fdba35f04  0.13          44.0
#
#    engagement_rate
# 0             5.88
# 1             0.00
# 2             0.00
# 3             1.28
# 4             0.00

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# A fixed rule cannot capture the complex relationships between multiple content and search signals such as CTR, average position, engagement rate, search volume, and content characteristics. A page may perform well because of a combination of factors rather than a single value. Machine learning can learn these patterns from historical data and produce a more useful ranking than a simple if-statement. The results should be used as decision-support to help prioritize content improvements, not as guaranteed predictions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
